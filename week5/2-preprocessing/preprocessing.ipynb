# %% [markdown]
# # Preprocessing
#
# ### Outline
# - Case Folding (Uppercase to Lowercase)
# - Removing Noise (URLs, HTML tags, special characters, numbers)
# - Tokenization
# - Stopword Removal (before & after comparison)
# - Lemmatization (root words / kata dasar)

# %% [markdown]
# ## 1. Import Libraries & Load Data

# %%
# Install required libraries (run once)
# !pip install pandas nltk sastrawi matplotlib seaborn wordcloud
# Out:
# Requirement already satisfied: pandas in /home/lenovo/Documents/School/Sem6/PBA/pba-task-group/.env/lib/python3.14/site-packages (3.0.2)
# Requirement already satisfied: nltk in /home/lenovo/Documents/School/Sem6/PBA/pba-task-group/.env/lib/python3.14/site-packages (3.9.4)
# Requirement already satisfied: sastrawi in /home/lenovo/Documents/School/Sem6/PBA/pba-task-group/.env/lib/python3.14/site-packages (1.0.1)
# Requirement already satisfied: matplotlib in /home/lenovo/Documents/School/Sem6/PBA/pba-task-group/.env/lib/python3.14/site-packages (3.10.9)
# Requirement already satisfied: seaborn in /home/lenovo/Documents/School/Sem6/PBA/pba-task-group/.env/lib/python3.14/site-packages (0.13.2)
# Requirement already satisfied: wordcloud in /home/lenovo/Documents/School/Sem6/PBA/pba-task-group/.env/lib/python3.14/site-packages (1.9.6)
# Requirement already satisfied: numpy>=2.3.3 in /home/lenovo/Documents/School/Sem6/PBA/pba-task-group/.env/lib/python3.14/site-packages (from pandas) (2.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/lenovo/Documents/School/Sem6/PBA/pba-task-group/.env/lib/python3.14/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: click in /home/lenovo/Documents/School/Sem6/PBA/pba-task-group/.env/lib/python3.14/site-packages (from nltk) (8.3.2)
# Requirement already satisfied: joblib in /home/lenovo/Documents/School/Sem6/PBA/pba-task-group/.env/lib/python3.14/site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /home/lenovo/Documents/School/Sem6/PBA/pba-task-group/.env/lib/python3.14/site-packages (from nltk) (2026.4.4)
# Requirement already satisfied: tqdm in /home/lenovo/Documents/School/Sem6/PBA/pba-task-group/.env/lib/python3.14/site-packages (from nltk) (4.67.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/lenovo/Documents/School/Sem6/PBA/pba-task-group/.env/lib/python3.14/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/lenovo/Documents/School/Sem6/PBA/pba-task-group/.env/lib/python3.14/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/lenovo/Documents/School/Sem6/PBA/pba-task-group/.env/lib/python3.14/site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/lenovo/Documents/School/Sem6/PBA/pba-task-group/.env/lib/python3.14/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/lenovo/Documents/School/Sem6/PBA/pba-task-group/.env/lib/python3.14/site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in /home/lenovo/Documents/School/Sem6/PBA/pba-task-group/.env/lib/python3.14/site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /home/lenovo/Documents/School/Sem6/PBA/pba-task-group/.env/lib/python3.14/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: six>=1.5 in /home/lenovo/Documents/School/Sem6/PBA/pba-task-group/.env/lib/python3.14/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 25.3 -> 26.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import re
import string
import warnings
warnings.filterwarnings('ignore')

# NLP Libraries
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# Indonesian stemmer (for Bahasa Indonesia articles if applicable)
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
from collections import Counter

# Download NLTK data
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('averaged_perceptron_tagger')

print('All libraries loaded successfully.')
# Out:
# All libraries loaded successfully.
# [nltk_data] Downloading package punkt to /home/lenovo/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /home/lenovo/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/lenovo/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/lenovo/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/lenovo/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/lenovo/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
df = pd.read_csv('../dataset/dataset.csv')

print(f'Dataset loaded: {df.shape[0]} rows, {df.shape[1]} columns')
print(f'Columns: {list(df.columns)}')
df.head()
# Out:
# Dataset loaded: 1001 rows, 4 columns
# Columns: ['url', 'judul', 'konten', 'manual sentiment']
#                                                  url  \
# 0  https://www.cnbcindonesia.com/research/2025012...
# 1  https://www.cnbcindonesia.com/research/2025012...
# 2  https://www.cnbcindonesia.com/research/2025012...
# 3  https://www.cnbcindonesia.com/research/2025030...
# 4  https://indodax.com/academy/bitcoin-200k-predi...
#
#                                                judul  \
# 0  Trump Sebar Exceutive Order: Emang Semengerika...
# 1  Alasan Rupiah 'Berpesta' di Pelantikan Trump, ...
# 2  Trump Beri Kabar Baik, Saatnya Menunggu Dolar ...
# 3  IHSG Merah Lagi, Begini Penjelasan dari Analis...
# 4  Bernstein: Bitcoin Bisa Naik 2x Lipat! Target ...
#
#                                               konten manual sentiment
# 0  Jakarta, CNBC Indonesia -Amerika Serikat (AS) ...         Positive
# 1  Jakarta, CNBC Indonesia -Nilai tukar rupiah te...         Positive
# 2  Jakarta, CNBC Indonesia-Pasar keuangan Indones...         Positive
# 3  Jakarta, CNBC Indonesia -Indeks Harga Saham Ga...         Negative
# 4  HargaBitcoin(BTC)pernah melewati angka terting...         Positive

# %% [markdown]
# ## 2. Initial Data Exploration

# %%
df.columns = df.columns.str.strip().str.lower()

print('Column names after standardization:', list(df.columns))
print()
print(df.info())
# Out:
# Column names after standardization: ['url', 'judul', 'konten', 'manual sentiment']
#
# <class 'pandas.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   url               1001 non-null   str
#  1   judul             1001 non-null   str
#  2   konten            1001 non-null   str
#  3   manual sentiment  999 non-null    str
# dtypes: str(4)
# memory usage: 4.3 MB
# None

# %%
# Basic statistics
print('=== Dataset Overview ===')
print(f'Total articles     : {len(df)}')
print(f'Duplicate rows     : {df.duplicated().sum()}')
print(f'Missing values per column:')
print(df.isnull().sum())
print()

# Content length distribution
df['konten_length'] = df['konten'].astype(str).apply(len)
df['konten_word_count'] = df['konten'].astype(str).apply(lambda x: len(x.split()))

print(f'Content length (characters) - min: {df["konten_length"].min()}, '
      f'max: {df["konten_length"].max()}, '
      f'mean: {df["konten_length"].mean():.0f}')
print(f'Content word count - min: {df["konten_word_count"].min()}, '
      f'max: {df["konten_word_count"].max()}, '
      f'mean: {df["konten_word_count"].mean():.0f}')
# Out:
# === Dataset Overview ===
# Total articles     : 1001
# Duplicate rows     : 0
# Missing values per column:
# url                 0
# judul               0
# konten              0
# manual sentiment    2
# dtype: int64
#
# Content length (characters) - min: 154, max: 26287, mean: 4307
# Content word count - min: 20, max: 3601, mean: 581

# %%
# Visualize content length distribution
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].hist(df['konten_length'], bins=50, color='steelblue', edgecolor='white')
axes[0].set_title('Distribution of Article Length (Characters)')
axes[0].set_xlabel('Character Count')
axes[0].set_ylabel('Frequency')

axes[1].hist(df['konten_word_count'], bins=50, color='coral', edgecolor='white')
axes[1].set_title('Distribution of Article Length (Words)')
axes[1].set_xlabel('Word Count')
axes[1].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Data Cleaning

# %%
# Remove duplicates
before_dedup = len(df)
df = df.drop_duplicates(subset=['konten'], keep='first').reset_index(drop=True)
after_dedup = len(df)
print(f'Removed {before_dedup - after_dedup} duplicate articles.')
print(f'Remaining articles: {after_dedup}')
# Out:
# Removed 2 duplicate articles.
# Remaining articles: 999

# %%
# Remove rows with missing or empty content

before_clean = len(df)
df = df.dropna(subset=['konten']).reset_index(drop=True)
df = df[df['konten'].astype(str).str.strip() != ''].reset_index(drop=True)
after_clean = len(df)
print(f'Removed {before_clean - after_clean} rows with empty/missing content.')
print(f'Remaining articles: {after_clean}')
# Out:
# Removed 0 rows with empty/missing content.
# Remaining articles: 999

# %% [markdown]
# ## 4. Text Preprocessing Pipeline
#
# The preprocessing pipeline includes:
# 1. Case folding (uppercase to lowercase)
# 2. Noise removal (URLs, HTML tags, special characters, extra whitespace)
# 3. Tokenization
# 4. Stopword removal
# 5. Lemmatization

# %% [markdown]
# ### 4.1 Case Folding (Uppercase to Lowercase)

# %%
# Convert all text to lowercase
df['konten_clean'] = df['konten'].astype(str).str.lower()

print('Case folding completed.')
print('\nBefore (sample):')
print(df['konten'].iloc[0][:200])
print('\nAfter (sample):')
print(df['konten_clean'].iloc[0][:200])
# Out:
# Case folding completed.
#
# Before (sample):
# Jakarta, CNBC Indonesia -Amerika Serikat (AS) secara resmi memiliki Presiden baru yang disambut positif karena agenda pro-bisnis yang dibawanya.
# Presiden Amerika Serikat (AS) Donald Trump resmi dilant
#
# After (sample):
# jakarta, cnbc indonesia -amerika serikat (as) secara resmi memiliki presiden baru yang disambut positif karena agenda pro-bisnis yang dibawanya.
# presiden amerika serikat (as) donald trump resmi dilant

# %% [markdown]
# ### 4.2 Noise Removal

# %%
def remove_noise(text):
    
    # Remove HTML tags
    text = re.sub(r'<[^>]+>', ' ', text)

    # Remove URLs
    text = re.sub(r'https?://\S+|www\.\S+', ' ', text)

    # Remove email addresses
    text = re.sub(r'\S+@\S+', ' ', text)

    # Remove mentions
    text = re.sub(r'@\w+', ' ', text)

    # Remove hashtag symbol (keep the word)
    text = re.sub(r'#', '', text)

    # Remove numbers
    text = re.sub(r'\d+', ' ', text)

    # Remove special characters and punctuation
    text = re.sub(r'[^\w\s]', ' ', text)

    # Remove single characters (except 'a' and 'i' for English)
    text = re.sub(r'\b[b-hj-z]\b', ' ', text)

    # Remove extra whitespace
    text = re.sub(r'\s+', ' ', text).strip()

    return text

df['konten_clean'] = df['konten_clean'].apply(remove_noise)

print('Noise removal completed.')
print('\nSample result:')
print(df['konten_clean'].iloc[0][:300])
# Out:
# Noise removal completed.
#
# Sample result:
# jakarta cnbc indonesia amerika serikat as secara resmi memiliki presiden baru yang disambut positif karena agenda pro bisnis yang dibawanya presiden amerika serikat as donald trump resmi dilantik pada senin waktu as secara umum dalam pidatonya trump mengungkapkan kebijakan perdagangan proteksionis y

# %% [markdown]
# ### 4.3 Tokenization

# %%
# Tokenize the cleaned text into individual words

df['tokens'] = df['konten_clean'].apply(word_tokenize)

print('Tokenization completed.')
print(f'\nSample tokens (first 20 tokens of first article):')
print(df['tokens'].iloc[0][:20])
# Out:
# Tokenization completed.
#
# Sample tokens (first 20 tokens of first article):
# ['jakarta', 'cnbc', 'indonesia', 'amerika', 'serikat', 'as', 'secara', 'resmi', 'memiliki', 'presiden', 'baru', 'yang', 'disambut', 'positif', 'karena', 'agenda', 'pro', 'bisnis', 'yang', 'dibawanya']

# %%
df['n_tokens_before_stopwords'] = df['tokens'].apply(len)

# Also store the text version before stopword removal
df['text_before_stopwords'] = df['tokens'].apply(lambda x: ' '.join(x))

print('Token counts before stopword removal:')
print(df['n_tokens_before_stopwords'].describe())
# Out:
# Token counts before stopword removal:
# count     999.000000
# mean      574.211211
# std       546.954696
# min        18.000000
# 25%       252.000000
# 50%       382.000000
# 75%       683.500000
# max      3573.000000
# Name: n_tokens_before_stopwords, dtype: float64

# %% [markdown]
# ### 4.4 Stopword Removal

# %%
# English stopwords
stop_words_en = set(stopwords.words('english'))

# Indonesian stopwords
stop_words_id = set(stopwords.words('indonesian'))

# Combine both
combined_stopwords = stop_words_en.union(stop_words_id)

# Add custom domain-specific stopwords
# (common words in news articles that do not carry meaning)
custom_stopwords = {
    'said', 'also', 'would', 'could', 'one', 'two', 'new',
    'like', 'get', 'make', 'may', 'us', 'year', 'years',
    'reuters', 'ap', 'afp', 'foto', 'baca', 'juga',
    'jakarta', 'kompas', 'detik', 'cnbc', 'cnn', 'bbc',
    'read', 'more', 'click', 'share', 'comment', 'subscribe'
}
combined_stopwords = combined_stopwords.union(custom_stopwords)

print(f'Total stopwords: {len(combined_stopwords)}')
print(f'  - English: {len(stop_words_en)}')
print(f'  - Indonesian: {len(stop_words_id)}')
print(f'  - Custom: {len(custom_stopwords)}')
# Out:
# Total stopwords: 985
#   - English: 198
#   - Indonesian: 757
#   - Custom: 32

# %%
# Apply stopword removal
df['tokens_no_stopwords'] = df['tokens'].apply(
    lambda tokens: [word for word in tokens if word not in combined_stopwords]
)

df['n_tokens_after_stopwords'] = df['tokens_no_stopwords'].apply(len)

# Text version after stopword removal
df['text_after_stopwords'] = df['tokens_no_stopwords'].apply(lambda x: ' '.join(x))

print('Stopword removal completed.')
print(f'\nAverage tokens BEFORE stopwords: {df["n_tokens_before_stopwords"].mean():.0f}')
print(f'Average tokens AFTER stopwords : {df["n_tokens_after_stopwords"].mean():.0f}')
print(f'Average reduction              : {((df["n_tokens_before_stopwords"].mean() - df["n_tokens_after_stopwords"].mean()) / df["n_tokens_before_stopwords"].mean() * 100):.1f}%')
# Out:
# Stopword removal completed.
#
# Average tokens BEFORE stopwords: 574
# Average tokens AFTER stopwords : 331
# Average reduction              : 42.3%

# %%
# COMPARISON: Before vs After Stopword Removal

print('=== Before vs After Stopword Removal (Sample Article #1) ===')
print()
print('BEFORE stopwords (first 30 tokens):')
print(df['tokens'].iloc[0][:30])
print(f'Total tokens: {df["n_tokens_before_stopwords"].iloc[0]}')
print()
print('AFTER stopwords (first 30 tokens):')
print(df['tokens_no_stopwords'].iloc[0][:30])
print(f'Total tokens: {df["n_tokens_after_stopwords"].iloc[0]}')
# Out:
# === Before vs After Stopword Removal (Sample Article #1) ===
#
# BEFORE stopwords (first 30 tokens):
# ['jakarta', 'cnbc', 'indonesia', 'amerika', 'serikat', 'as', 'secara', 'resmi', 'memiliki', 'presiden', 'baru', 'yang', 'disambut', 'positif', 'karena', 'agenda', 'pro', 'bisnis', 'yang', 'dibawanya', 'presiden', 'amerika', 'serikat', 'as', 'donald', 'trump', 'resmi', 'dilantik', 'pada', 'senin']
# Total tokens: 1106
#
# AFTER stopwords (first 30 tokens):
# ['indonesia', 'amerika', 'serikat', 'resmi', 'memiliki', 'presiden', 'disambut', 'positif', 'agenda', 'pro', 'bisnis', 'dibawanya', 'presiden', 'amerika', 'serikat', 'donald', 'trump', 'resmi', 'dilantik', 'senin', 'pidatonya', 'trump', 'kebijakan', 'perdagangan', 'proteksionis', 'dikhawatirkan', 'agresif', 'diterapkan', 'terukur', 'trump']
# Total tokens: 596

# %% [markdown]
# ### 4.5 Lemmatization

# %%
factory = StemmerFactory()
stemmer_id = factory.create_stemmer()

def stem_tokens_id(tokens):
    """Stem Indonesian tokens using Sastrawi."""
    return [stemmer_id.stem(token) for token in tokens]

df['tokens_lemmatized'] = df['tokens_no_stopwords'].apply(stem_tokens_id)

print('Lemmatization completed.')
print(f'\nSample: BEFORE lemmatization (first 15 tokens):')
print(df['tokens'].iloc[0][:15])
print(f'\nSample: AFTER lemmatization (first 15 tokens):')
print(df['tokens_lemmatized'].iloc[0][:15])
# Out:
# Lemmatization completed.
#
# Sample: BEFORE lemmatization (first 15 tokens):
# ['jakarta', 'cnbc', 'indonesia', 'amerika', 'serikat', 'as', 'secara', 'resmi', 'memiliki', 'presiden', 'baru', 'yang', 'disambut', 'positif', 'karena']
#
# Sample: AFTER lemmatization (first 15 tokens):
# ['indonesia', 'amerika', 'serikat', 'resmi', 'milik', 'presiden', 'sambut', 'positif', 'agenda', 'pro', 'bisnis', 'bawa', 'presiden', 'amerika', 'serikat']

# %%
# Create final clean text column from lemmatized tokens

df['konten_preprocessed'] = df['tokens_lemmatized'].apply(lambda x: ' '.join(x))

print('Final preprocessed text created.')
print('\nSample:')
print(df['konten_preprocessed'].iloc[0][:300])
# Out:
# Final preprocessed text created.
#
# Sample:
# indonesia amerika serikat resmi milik presiden sambut positif agenda pro bisnis bawa presiden amerika serikat donald trump resmi lantik senin pidato trump bijak dagang proteksionis khawatir agresif terap ukur trump bawa agenda ambisius liput reformasi dagang imigrasi mangkas pajak deregulasi bijak p

# %% [markdown]
# ## 5. Word Count Statistics (Before & After Stopwords)

# %%
comparison_df = df[['n_tokens_before_stopwords', 'n_tokens_after_stopwords']].describe()
comparison_df.columns = ['Before Stopwords', 'After Stopwords']
print(comparison_df.round(2))
# Out:
#        Before Stopwords  After Stopwords
# count            999.00           999.00
# mean             574.21           331.22
# std              546.95           318.25
# min               18.00            13.00
# 25%              252.00           140.00
# 50%              382.00           217.00
# 75%              683.50           390.50
# max             3573.00          2032.00

# %%
# Visualization: Before vs After stopword removal
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].hist(df['n_tokens_before_stopwords'], bins=50, color='steelblue',
             edgecolor='white', alpha=0.7, label='Before Stopwords')
axes[0].hist(df['n_tokens_after_stopwords'], bins=50, color='coral',
             edgecolor='white', alpha=0.7, label='After Stopwords')
axes[0].set_title('Token Count Distribution: Before vs After Stopwords')
axes[0].set_xlabel('Number of Tokens')
axes[0].set_ylabel('Frequency')
axes[0].legend()

# Box plot comparison
box_data = pd.DataFrame({
    'Before Stopwords': df['n_tokens_before_stopwords'],
    'After Stopwords': df['n_tokens_after_stopwords']
})
box_data.boxplot(ax=axes[1], grid=False)
axes[1].set_title('Token Count: Before vs After Stopwords')
axes[1].set_ylabel('Number of Tokens')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Top 100 Frequency Words

# %%
all_tokens = [token for tokens_list in df['tokens_lemmatized'] for token in tokens_list]
word_freq = Counter(all_tokens)

# Top 100 words
top_100 = word_freq.most_common(100)

# Create a DataFrame for display
top_100_df = pd.DataFrame(top_100, columns=['Word', 'Frequency'])
top_100_df.index = top_100_df.index + 1  # Start index from 1
top_100_df.index.name = 'Rank'

print(f'Total unique words in corpus: {len(word_freq)}')
print(f'Total words in corpus: {len(all_tokens)}')
print()
print('=== Top 100 Most Frequent Words ===')
print(top_100_df.to_string())
# Out:
# Total unique words in corpus: 13496
# Total words in corpus: 330889
#
# === Top 100 Most Frequent Words ===
#                Word  Frequency
# Rank
# 1             tarif      10172
# 2             trump       6292
# 3            negara       5911
# 4         indonesia       5309
# 5            dagang       5295
# 6             china       3808
# 7            persen       3445
# 8             impor       3288
# 9           ekonomi       3123
# 10            bijak       3101
# 11          amerika       2576
# 12           produk       2569
# 13            pasar       2434
# 14         perintah       2357
# 15           barang       2194
# 16         presiden       2078
# 17           ekspor       2060
# 18             laku       1992
# 19             kena       1866
# 20          serikat       1803
# 21            usaha       1780
# 22            harga       1726
# 23           global       1654
# 24           dampak       1636
# 25            turun       1630
# 26          tingkat       1629
# 27            dunia       1268
# 28         industri       1252
# 29             naik       1216
# 30            kerja       1207
# 31            nilai       1204
# 32          menteri       1197
# 33           miliar       1191
# 34           donald       1162
# 35           negeri       1157
# 36           perang       1106
# 37        negosiasi       1083
# 38           kanada       1071
# 39            masuk       1035
# 40          langkah       1003
# 41             kuat        977
# 42             umum        962
# 43            terap        956
# 44           tumbuh        921
# 45             uang        912
# 46            eropa        897
# 47         produksi        874
# 48            milik        854
# 49            april        853
# 50            balas        845
# 51            capai        840
# 52           dollar        834
# 53          meksiko        818
# 54            tekan        791
# 55            besar        790
# 56           sektor        789
# 57            saham        766
# 58            mitra        758
# 59           tambah        747
# 60        investasi        736
# 61            utama        725
# 62            salah        721
# 63       resiprokal        694
# 64          potensi        691
# 65              bea        674
# 66            dasar        672
# 67               rp        661
# 68         nasional        645
# 69             kait        634
# 70          sepakat        593
# 71             temu        591
# 72           hubung        589
# 73            ancam        588
# 74    internasional        586
# 75            putus        582
# 76             bank        575
# 77            hasil        575
# 78             beli        575
# 79            biaya        564
# 80         langsung        559
# 81          banding        556
# 82          defisit        545
# 83            bayar        542
# 84             juta        541
# 85           dorong        540
# 86           kurang        534
# 87            hadap        531
# 88             jual        530
# 89            alami        525
# 90             tuju        521
# 91            catat        521
# 92           akibat        521
# 93              uni        516
# 94            janji        513
# 95            pasok        504
# 96            batas        495
# 97            saing        493
# 98         khawatir        485
# 99             ubah        484
# 100           pilih        483

# %%
# Visualization: Top 30 words bar chart

top_30 = top_100_df.head(30)

plt.figure(figsize=(14, 7))
plt.barh(range(len(top_30)), top_30['Frequency'].values, color='steelblue')
plt.yticks(range(len(top_30)), top_30['Word'].values)
plt.gca().invert_yaxis()
plt.xlabel('Frequency')
plt.title('Top 30 Most Frequent Words (After Preprocessing)')
plt.tight_layout()
plt.show()

# %%
# Word Cloud visualization

wordcloud_text = ' '.join(all_tokens)
wordcloud = WordCloud(
    width=1200,
    height=600,
    background_color='white',
    max_words=200,
    colormap='viridis',
    random_state=42
).generate(wordcloud_text)

plt.figure(figsize=(14, 7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud: Trump Tariff News Articles', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7. Export Preprocessed Dataset

# %%
df
# Out:
#                                                    url  \
# 0    https://www.cnbcindonesia.com/research/2025012...
# 1    https://www.cnbcindonesia.com/research/2025012...
# 2    https://www.cnbcindonesia.com/research/2025012...
# 3    https://www.cnbcindonesia.com/research/2025030...
# 4    https://indodax.com/academy/bitcoin-200k-predi...
# ..                                                 ...
# 994  https://voi.id/teknologi/489452/produsen-mesin...
# 995  https://www.liputan6.com/bisnis/read/6058462/d...
# 996  https://kabar24.bisnis.com/read/20250622/19/18...
# 997  https://www.cnbcindonesia.com/tech/20250620153...
# 998  https://www.cnbcindonesia.com/news/20250628200...
#
#                                                  judul  \
# 0    Trump Sebar Exceutive Order: Emang Semengerika...
# 1    Alasan Rupiah 'Berpesta' di Pelantikan Trump, ...
# 2    Trump Beri Kabar Baik, Saatnya Menunggu Dolar ...
# 3    IHSG Merah Lagi, Begini Penjelasan dari Analis...
# 4    Bernstein: Bitcoin Bisa Naik 2x Lipat! Target ...
# ..                                                 ...
# 994  Produsen Mesin Bitcoin China Pindahkan Produks...
# 995  Donald Trump Kembali Tekan Ketua The Fed Jerom...
# 996  Donald Trump Serang Iran, Ekonomi Global Bakal...
# 997  Trump 'Palak' Raksasa Teknologi Rp 900 Triliun...
# 998  Tarif Trump Pukul Jatuh Industri Otomotif Ingg...
#
#                                                 konten manual sentiment  \
# 0    Jakarta, CNBC Indonesia -Amerika Serikat (AS) ...         Positive
# 1    Jakarta, CNBC Indonesia -Nilai tukar rupiah te...         Positive
# 2    Jakarta, CNBC Indonesia-Pasar keuangan Indones...         Positive
# 3    Jakarta, CNBC Indonesia -Indeks Harga Saham Ga...         Negative
# 4    HargaBitcoin(BTC)pernah melewati angka terting...         Positive
# ..                                                 ...              ...
# 994  JAKARTA - Tiga produsen mesin penambang bitcoi...         Negative
# 995  Presiden Amerika Serikat (AS) Donald Trump men...         Positive
# 996  Bisnis.com,JAKARTA — Serangan Amerika Serikat ...         Negative
# 997  Jakarta, CNBC Indonesia -Perusahaan semikonduk...              NaN
# 998  Jakarta, CNBC Indonesia -Kebijakan tarif Presi...              NaN
#
#      konten_length  konten_word_count  \
# 0             8328               1110
# 1             2925                399
# 2            13102               1747
# 3             5158                722
# 4             4767                616
# ..             ...                ...
# 994           3756                506
# 995           3322                447
# 996           4713                627
# 997           2830                387
# 998           2826                389
#
#                                           konten_clean  \
# 0    jakarta cnbc indonesia amerika serikat as seca...
# 1    jakarta cnbc indonesia nilai tukar rupiah terh...
# 2    jakarta cnbc indonesia pasar keuangan indonesi...
# 3    jakarta cnbc indonesia indeks harga saham gabu...
# 4    hargabitcoin btc pernah melewati angka terting...
# ..                                                 ...
# 994  jakarta tiga produsen mesin penambang bitcoin ...
# 995  presiden amerika serikat as donald trump menga...
# 996  bisnis com jakarta serangan amerika serikat as...
# 997  jakarta cnbc indonesia perusahaan semikondukto...
# 998  jakarta cnbc indonesia kebijakan tarif preside...
#
#                                                 tokens  \
# 0    [jakarta, cnbc, indonesia, amerika, serikat, a...
# 1    [jakarta, cnbc, indonesia, nilai, tukar, rupia...
# 2    [jakarta, cnbc, indonesia, pasar, keuangan, in...
# 3    [jakarta, cnbc, indonesia, indeks, harga, saha...
# 4    [hargabitcoin, btc, pernah, melewati, angka, t...
# ..                                                 ...
# 994  [jakarta, tiga, produsen, mesin, penambang, bi...
# 995  [presiden, amerika, serikat, as, donald, trump...
# 996  [bisnis, com, jakarta, serangan, amerika, seri...
# 997  [jakarta, cnbc, indonesia, perusahaan, semikon...
# 998  [jakarta, cnbc, indonesia, kebijakan, tarif, p...
#
#      n_tokens_before_stopwords  \
# 0                         1106
# 1                          387
# 2                         1699
# 3                          694
# 4                          632
# ..                         ...
# 994                        499
# 995                        448
# 996                        632
# 997                        386
# 998                        377
#
#                                  text_before_stopwords  \
# 0    jakarta cnbc indonesia amerika serikat as seca...
# 1    jakarta cnbc indonesia nilai tukar rupiah terh...
# 2    jakarta cnbc indonesia pasar keuangan indonesi...
# 3    jakarta cnbc indonesia indeks harga saham gabu...
# 4    hargabitcoin btc pernah melewati angka terting...
# ..                                                 ...
# 994  jakarta tiga produsen mesin penambang bitcoin ...
# 995  presiden amerika serikat as donald trump menga...
# 996  bisnis com jakarta serangan amerika serikat as...
# 997  jakarta cnbc indonesia perusahaan semikondukto...
# 998  jakarta cnbc indonesia kebijakan tarif preside...
#
#                                    tokens_no_stopwords  \
# 0    [indonesia, amerika, serikat, resmi, memiliki,...
# 1    [indonesia, nilai, tukar, rupiah, dolar, ameri...
# 2    [indonesia, pasar, keuangan, indonesia, mengua...
# 3    [indonesia, indeks, harga, saham, gabungan, ih...
# 4    [hargabitcoin, btc, melewati, angka, tertinggi...
# ..                                                 ...
# 994  [produsen, mesin, penambang, bitcoin, terbesar...
# 995  [presiden, amerika, serikat, donald, trump, me...
# 996  [bisnis, com, serangan, amerika, serikat, fasi...
# 997  [indonesia, perusahaan, semikonduktor, amerika...
# 998  [indonesia, kebijakan, tarif, presiden, amerik...
#
#      n_tokens_after_stopwords  \
# 0                         596
# 1                         217
# 2                        1047
# 3                         415
# 4                         340
# ..                        ...
# 994                       297
# 995                       240
# 996                       379
# 997                       213
# 998                       207
#
#                                   text_after_stopwords  \
# 0    indonesia amerika serikat resmi memiliki presi...
# 1    indonesia nilai tukar rupiah dolar amerika ser...
# 2    indonesia pasar keuangan indonesia menguat pel...
# 3    indonesia indeks harga saham gabungan ihsg amb...
# 4    hargabitcoin btc melewati angka tertinggi kisa...
# ..                                                 ...
# 994  produsen mesin penambang bitcoin terbesar duni...
# 995  presiden amerika serikat donald trump mengaku ...
# 996  bisnis com serangan amerika serikat fasilitas ...
# 997  indonesia perusahaan semikonduktor amerika ser...
# 998  indonesia kebijakan tarif presiden amerika ser...
#
#                                      tokens_lemmatized  \
# 0    [indonesia, amerika, serikat, resmi, milik, pr...
# 1    [indonesia, nilai, tukar, rupiah, dolar, ameri...
# 2    [indonesia, pasar, uang, indonesia, kuat, lant...
# 3    [indonesia, indeks, harga, saham, gabung, ihsg...
# 4    [hargabitcoin, btc, lewat, angka, tinggi, kisa...
# ..                                                 ...
# 994  [produsen, mesin, tambang, bitcoin, besar, dun...
# 995  [presiden, amerika, serikat, donald, trump, ak...
# 996  [bisnis, com, serang, amerika, serikat, fasili...
# 997  [indonesia, usaha, semikonduktor, amerika, ser...
# 998  [indonesia, bijak, tarif, presiden, amerika, s...
#
#                                    konten_preprocessed
# 0    indonesia amerika serikat resmi milik presiden...
# 1    indonesia nilai tukar rupiah dolar amerika ser...
# 2    indonesia pasar uang indonesia kuat lantik don...
# 3    indonesia indeks harga saham gabung ihsg ambru...
# 4    hargabitcoin btc lewat angka tinggi kisara pic...
# ..                                                 ...
# 994  produsen mesin tambang bitcoin besar dunia chi...
# 995  presiden amerika serikat donald trump aku sera...
# 996  bisnis com serang amerika serikat fasilitas nu...
# 997  indonesia usaha semikonduktor amerika serikat ...
# 998  indonesia bijak tarif presiden amerika serikat...
#
# [999 rows x 15 columns]

# %%
df_export = df.copy()
df_export.drop(columns=['konten_word_count',	'konten_clean',	'tokens',	'n_tokens_before_stopwords',	'text_before_stopwords',	'tokens_no_stopwords',	'n_tokens_after_stopwords',	'text_after_stopwords',	'tokens_lemmatized'], inplace=True)

df_export.head()
# Out:
#                                                  url  \
# 0  https://www.cnbcindonesia.com/research/2025012...
# 1  https://www.cnbcindonesia.com/research/2025012...
# 2  https://www.cnbcindonesia.com/research/2025012...
# 3  https://www.cnbcindonesia.com/research/2025030...
# 4  https://indodax.com/academy/bitcoin-200k-predi...
#
#                                                judul  \
# 0  Trump Sebar Exceutive Order: Emang Semengerika...
# 1  Alasan Rupiah 'Berpesta' di Pelantikan Trump, ...
# 2  Trump Beri Kabar Baik, Saatnya Menunggu Dolar ...
# 3  IHSG Merah Lagi, Begini Penjelasan dari Analis...
# 4  Bernstein: Bitcoin Bisa Naik 2x Lipat! Target ...
#
#                                               konten manual sentiment  \
# 0  Jakarta, CNBC Indonesia -Amerika Serikat (AS) ...         Positive
# 1  Jakarta, CNBC Indonesia -Nilai tukar rupiah te...         Positive
# 2  Jakarta, CNBC Indonesia-Pasar keuangan Indones...         Positive
# 3  Jakarta, CNBC Indonesia -Indeks Harga Saham Ga...         Negative
# 4  HargaBitcoin(BTC)pernah melewati angka terting...         Positive
#
#    konten_length                                konten_preprocessed
# 0           8328  indonesia amerika serikat resmi milik presiden...
# 1           2925  indonesia nilai tukar rupiah dolar amerika ser...
# 2          13102  indonesia pasar uang indonesia kuat lantik don...
# 3           5158  indonesia indeks harga saham gabung ihsg ambru...
# 4           4767  hargabitcoin btc lewat angka tinggi kisara pic...

# %%
df_export.to_csv('../preprocessed/dataset_preprocessed.csv', index=False, encoding='utf-8')
print(f'Export dataset shape: {df_export.shape}')
print(f'Columns: {list(df_export.columns)}')
# Out:
# Export dataset shape: (999, 4)
# Columns: ['url', 'judul', 'konten', 'konten_clean']

# %%
df_export
# Out:
#                                                    url  \
# 0    https://www.cnbcindonesia.com/research/2025012...
# 1    https://www.cnbcindonesia.com/research/2025012...
# 2    https://www.cnbcindonesia.com/research/2025012...
# 3    https://www.cnbcindonesia.com/research/2025030...
# 4    https://indodax.com/academy/bitcoin-200k-predi...
# ..                                                 ...
# 994  https://voi.id/teknologi/489452/produsen-mesin...
# 995  https://www.liputan6.com/bisnis/read/6058462/d...
# 996  https://kabar24.bisnis.com/read/20250622/19/18...
# 997  https://www.cnbcindonesia.com/tech/20250620153...
# 998  https://www.cnbcindonesia.com/news/20250628200...
#
#                                                  judul  \
# 0    Trump Sebar Exceutive Order: Emang Semengerika...
# 1    Alasan Rupiah 'Berpesta' di Pelantikan Trump, ...
# 2    Trump Beri Kabar Baik, Saatnya Menunggu Dolar ...
# 3    IHSG Merah Lagi, Begini Penjelasan dari Analis...
# 4    Bernstein: Bitcoin Bisa Naik 2x Lipat! Target ...
# ..                                                 ...
# 994  Produsen Mesin Bitcoin China Pindahkan Produks...
# 995  Donald Trump Kembali Tekan Ketua The Fed Jerom...
# 996  Donald Trump Serang Iran, Ekonomi Global Bakal...
# 997  Trump 'Palak' Raksasa Teknologi Rp 900 Triliun...
# 998  Tarif Trump Pukul Jatuh Industri Otomotif Ingg...
#
#                                                 konten manual sentiment  \
# 0    Jakarta, CNBC Indonesia -Amerika Serikat (AS) ...         Positive
# 1    Jakarta, CNBC Indonesia -Nilai tukar rupiah te...         Positive
# 2    Jakarta, CNBC Indonesia-Pasar keuangan Indones...         Positive
# 3    Jakarta, CNBC Indonesia -Indeks Harga Saham Ga...         Negative
# 4    HargaBitcoin(BTC)pernah melewati angka terting...         Positive
# ..                                                 ...              ...
# 994  JAKARTA - Tiga produsen mesin penambang bitcoi...         Negative
# 995  Presiden Amerika Serikat (AS) Donald Trump men...         Positive
# 996  Bisnis.com,JAKARTA — Serangan Amerika Serikat ...         Negative
# 997  Jakarta, CNBC Indonesia -Perusahaan semikonduk...              NaN
# 998  Jakarta, CNBC Indonesia -Kebijakan tarif Presi...              NaN
#
#      konten_length                                konten_preprocessed
# 0             8328  indonesia amerika serikat resmi milik presiden...
# 1             2925  indonesia nilai tukar rupiah dolar amerika ser...
# 2            13102  indonesia pasar uang indonesia kuat lantik don...
# 3             5158  indonesia indeks harga saham gabung ihsg ambru...
# 4             4767  hargabitcoin btc lewat angka tinggi kisara pic...
# ..             ...                                                ...
# 994           3756  produsen mesin tambang bitcoin besar dunia chi...
# 995           3322  presiden amerika serikat donald trump aku sera...
# 996           4713  bisnis com serang amerika serikat fasilitas nu...
# 997           2830  indonesia usaha semikonduktor amerika serikat ...
# 998           2826  indonesia bijak tarif presiden amerika serikat...
#
# [999 rows x 6 columns]

# %%
# Select columns to export
export_cols = [
    'url',                         # Original URL
    'judul',                       # Original title
    'konten',                      # Original content (raw)
    # 'konten_clean',                # After case folding + noise removal
    # 'text_before_stopwords',       # Tokenized text before stopwords
    # 'n_tokens_before_stopwords',   # Token count before stopwords
    # 'text_after_stopwords',        # Text after stopword removal
    # 'n_tokens_after_stopwords',    # Token count after stopwords
    'konten_clean',         # Final preprocessed text (lemmatized)
    # 'tokens_lemmatized',           # Lemmatized token list
]

export_cols = [col for col in export_cols if col in df.columns]

df_export = df[export_cols].copy()

if 'tokens_lemmatized' in df_export.columns:
    df_export['tokens_lemmatized'] = df_export['tokens_lemmatized'].apply(
        lambda x: '|'.join(x) if isinstance(x, list) else x
    )

print(f'Export dataset shape: {df_export.shape}')
print(f'Columns: {list(df_export.columns)}')
df_export.head()
# Out:
# Export dataset shape: (999, 4)
# Columns: ['url', 'judul', 'konten', 'konten_clean']
#                                                  url  \
# 0  https://www.cnbcindonesia.com/research/2025012...
# 1  https://www.cnbcindonesia.com/research/2025012...
# 2  https://www.cnbcindonesia.com/research/2025012...
# 3  https://www.cnbcindonesia.com/research/2025030...
# 4  https://indodax.com/academy/bitcoin-200k-predi...
#
#                                                judul  \
# 0  Trump Sebar Exceutive Order: Emang Semengerika...
# 1  Alasan Rupiah 'Berpesta' di Pelantikan Trump, ...
# 2  Trump Beri Kabar Baik, Saatnya Menunggu Dolar ...
# 3  IHSG Merah Lagi, Begini Penjelasan dari Analis...
# 4  Bernstein: Bitcoin Bisa Naik 2x Lipat! Target ...
#
#                                               konten  \
# 0  Jakarta, CNBC Indonesia -Amerika Serikat (AS) ...
# 1  Jakarta, CNBC Indonesia -Nilai tukar rupiah te...
# 2  Jakarta, CNBC Indonesia-Pasar keuangan Indones...
# 3  Jakarta, CNBC Indonesia -Indeks Harga Saham Ga...
# 4  HargaBitcoin(BTC)pernah melewati angka terting...
#
#                                         konten_clean
# 0  jakarta cnbc indonesia amerika serikat as seca...
# 1  jakarta cnbc indonesia nilai tukar rupiah terh...
# 2  jakarta cnbc indonesia pasar keuangan indonesi...
# 3  jakarta cnbc indonesia indeks harga saham gabu...
# 4  hargabitcoin btc pernah melewati angka terting...
