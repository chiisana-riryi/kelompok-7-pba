# %% [markdown]
# # Combine Manual Sentiment

# %%
import pandas as pd


df1 = pd.read_csv("../dataset/dataset_preprocessed.csv")
df2 = pd.read_csv("../dataset/dataset.csv")

df1["manual_sentiment"] = df2["Manual Sentiment"]

df1.to_csv("../outputs/dataset_preprocessed_manual.csv")
