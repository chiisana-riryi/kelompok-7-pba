# %% [markdown]
# # 1. Load Libraries

# %%
import pandas as pd

# %% [markdown]
# # 2. Load Datasets

# %%
df_original = pd.read_csv("../../dataset/dataset.csv")
df_rag = pd.read_csv("../../outputs/RAG/rag_results.csv")

df_original.columns
# Out:
# Index(['url', 'judul', 'konten', 'manual sentiment'], dtype='str')

# %%
df_rag = df_rag.rename(columns={
    "sentiment": "manual sentiment",
    "text_id": "konten"
})
df_rag["judul"] = "Generated with FLAN-Base"
df_rag.columns
# Out:
# Index(['manual sentiment', 'text_en', 'konten', 'llm_generated', 'judul'], dtype='str')

# %% [markdown]
# # 3. Combine Datasets

# %%
df_original["llm_generated"] = False
combine_original_df = df_original[["konten", "manual sentiment", "llm_generated", "judul"]]

# %%
combine_rag_df = df_rag[["konten", "manual sentiment", "llm_generated", "judul"]]
combine_rag_df
# Out:
#                                                 konten manual sentiment  \
# 0    Trump mengkritik Indonesia atas tarif barang d...         Positive
# 1    Kebijakan tarif Trump dikritik karena prospek ...         Positive
# 2    Kebijakan tarif Donald Trump dan kinerja ekono...         Positive
# 3    Tarif yang telah berlaku selama bertahun-tahun...         Positive
# 4    Kebijakan tarif Presiden Donald Trump membantu...         Positive
# ..                                                 ...              ...
# 623  Kebijakan tarif Donald Trump telah meningkatka...          Neutral
# 624  Kebijakan tarif Donald Trump, Indonesia, dan A...          Neutral
# 625  Saya belum bisa mendapatkan informasinya, jadi...          Neutral
# 626  Artikel ini membahas tentang kebijakan tarif D...          Neutral
# 627  Artikel ini berfokus pada perdebatan yang seda...          Neutral
#
#      llm_generated                     judul
# 0             True  Generated with FLAN-Base
# 1             True  Generated with FLAN-Base
# 2             True  Generated with FLAN-Base
# 3             True  Generated with FLAN-Base
# 4             True  Generated with FLAN-Base
# ..             ...                       ...
# 623           True  Generated with FLAN-Base
# 624           True  Generated with FLAN-Base
# 625           True  Generated with FLAN-Base
# 626           True  Generated with FLAN-Base
# 627           True  Generated with FLAN-Base
#
# [628 rows x 4 columns]

# %%
df_combined = pd.concat([combine_original_df, combine_rag_df], axis=0, ignore_index=True)
df_combined.to_csv("../../outputs/RAG/dataset_rag_combined.csv", index=False)
